# %%
import boto3

s3 = boto3.resource('s3')

# s3 = boto3.client('s3')
response = s3.meta.client.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   ai-ml-week-2020-saude
#   aplicacoes-demo
#   aplicacoes-demo-sao-paulo
#   appstream2-36fb080bb8-us-west-2-126421527990
#   aws-athena-query-results-126421527990-us-west-2
#   aws-athena-query-results-sa-east-1-126421527990
#   aws-athena-query-results-us-east-1-126421527990
#   aws-athena-query-results-us-west-2-126421527990
#   aws-codestar-us-east-1-126421527990
#   aws-codestar-us-east-1-126421527990-democodestar-pipe
#   aws-codestar-us-east-1-126421527990-democodestarphp-pipe
#   aws-codestar-us-east-1-126421527990-prodest-pipe
#   aws-codestar-us-east-1-126421527990-sebraedf-pipe
#   aws-codestar-us-west-2-126421527990
#   aws-codestar-us-west-2-126421527990-codestarpython-pipeline
#   aws-codestar-us-west-2-126421527990-codestarstatic-pipeline
#   aws-config-bucket-126421527990
#   aws-glue-scripts-126421527990-us-west-2
#   aws-glue-temporary-126421527990-us-west-2
#   aws-logs-126421527990-sa-east-1
#   aws-logs-126421527990-us-east-1
#   billingcostexplorer
#   brain-company-natal
#   cf-templates-1pt0mglpyw0bd-ap-northeast-2
#   cf-templates-1pt0mglpyw0bd-ca-central-1
#   cf-templates-1pt0mglpyw0bd-eu-west-1
#   cf-templates-1pt0mglpyw0bd-sa-east-1
#   cf-templates-1pt0mglpyw0bd-us-east-1
#   cf-templates-1pt0mglpyw0bd-us-east-2
#   cf-templates-1pt0mglpyw0bd-us-west-2
#   cloud9demobucket
#   cloudberrybackup59349c2f-6144-4b89-95bd-f84e61d3221b
#   cloudtrail-melissa
#   cloudwatchlogs-melissa
#   codedeploy-livraria
#   codepipeline-us-west-2-782530591573
#   custom-labels-console-us-east-1-226decc1a6
#   deletemeafterconfigtest2
#   democodepipelineartifacts
#   do-not-delete-gatedgarden-audit-126421527990
#   elasticbeanstalk-sa-east-1-126421527990
#   elasticbeanstalk-us-east-1-126421527990
#   elasticbeanstalk-us-west-2-126421527990
#   elb-access-logs-melissa
#   estimaodontologia
#   fhir-service-dev-bulkexportresultsbucket-kwvi5be20lxt
#   fhir-service-dev-fhirbinarybucket-1l9t314k7tnbk
#   fhir-service-dev-fhirlogsbucket-637qdq00aquo
#   fhir-service-dev-gluescriptsbucket-e4moeakfo5ok
#   fhir-service-dev-serverlessdeploymentbucket-r73cl2wmi4du
#   fidimamografias-dev-serverlessdeploymentbucket-7bvlys21ebuz
#   helloworldpython-dev-serverlessdeploymentbucket-7nd1uexbclfg
#   iot-light-bulb
#   lab-orders-pipeline2-buildartifactsbucket-ccbmcb0385e6
#   lab-restaurants-pipeline-buildartifactsbucket-i4katpm2tssf
#   labs.essentials.training
#   labs.training
#   latam-tech-summit-2017-melissa
#   machine-learning-datasets
#   mammography-workshop
#   mammography-workshop-files-eu-west-1-126421527990
#   mammography-workshop-ireland
#   mammography-workshop-ohio
#   mammography-workshop-oregon
#   mammographyupload
#   mammographyuploadwebsite
#   mamografiasaifidi
#   melissa-brazil
#   melissa-oregon
#   melissa-virginia
#   mlops-us-east-1-126421527990
#   poc-bucket-analytics
#   podcast-braps
#   proposal-calculator-local
#   redshift-flights-lab-melissa
#   rekognition-video-console-demo-iad-melissar-booo8jh8aesw
#   rgs-task-data-1e5cf43a
#   s3-as-an-origin-for-cloudfront
#   sagemaker-studio-126421527990-ixkgja3pefg
#   sagemaker-studio-126421527990-ujiq3zkiaf
#   sagemaker-us-east-1-126421527990
#   sagemaker-us-west-2-126421527990
#   serverlessandmobiletraining
#   wellarchitectedreviews
#   workshop-backups
